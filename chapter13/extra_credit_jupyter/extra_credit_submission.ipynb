# %% [markdown]
# # Extra Credit: Getting Started with Jupyter Notebooks
# This notebook fulfills all requirements for the extra credit assignment from Zybooks Chapter 13.
#
# ---
#
# ## Instructions (as completed)
# 1. Pip, Jupyter, notebook, and seaborn were installed.
# 2. Jupyter Lab was launched.
# 3. The following cells correspond to In [1], In [2], and In [3] from Zybooks.
# 4. All outputs are present below for screenshot submission.

# %%
# In [1] from Zybooks
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load the penguins dataset
penguins = sns.load_dataset('penguins')
penguins.head()

# %% [markdown]
# *Above: Preview of the penguins dataset (screenshot this table for submission)*

# %%
# In [2] from Zybooks
# Create a scatterplot
sns.scatterplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', hue='species')
plt.title('Penguins: Bill Length vs Bill Depth')
plt.show()

# %% [markdown]
# *Above: Scatterplot of bill length vs bill depth (screenshot this plot for submission)*

# %%
# In [3] from Zybooks
# Display summary statistics
penguins.describe()

# %% [markdown]
# *Above: Summary statistics for the penguins dataset (screenshot this output for submission)*
